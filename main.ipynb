# %% [markdown]
# # Imports

# %%
import src.numerical.num_caseI as numI
import src.numerical.num_caseII as numII
import src.theorems.thm_caseI as thmI
import src.theorems.thm_caseII as thmII
import src.theorems.thm_total as thm_tot
import src.plotting as myplt

import numpy as np

# %% [markdown]
# ## Verification

# %% [markdown]
# ## Case I

# %%
#Verification
alpha = 3/5
beta = 0.2
gamma = 0.1
delta = 0.25
n = 5
k = 3
e_top_s = 2
trunc=False
params = (alpha, beta, gamma, delta, n, k, e_top_s)
thmI.avg_of_equilibrium_M(params, verify=True)

# %%
#Verification
alpha = 3/5
beta = 0.2
gamma = 0.1
delta = 0.25
n = 5
k = 3
e_top_s = n * 0.9
trunc=False
params = (alpha, beta, gamma, delta, n, k, e_top_s)
thmI.avg_of_equilibrium_M(params, verify=True)

# %% [markdown]
# ## Case II

# %%
#Verification
alpha = 3/5
beta = 0.2*0
gamma = 0.1
delta = 0.25
n = 5
k = 2
e_top_s = 1
trunc=False
params = (alpha, beta, gamma, delta, n, k, e_top_s, trunc)
thmII.thm_sum_of_expressed_equilibrium_case2_M(
    params,
    verify=True
)

# %%
# All asserts passing!
alpha = 30/50
beta = 0.2*0
gamma = 0.1
delta = 0.25
n = 50
k = 18
e_top_s = 1
trunc=False
params = (alpha, beta, gamma, delta, n, k, e_top_s, trunc)
print("thm_sum:",
thmII.thm_sum_of_expressed_equilibrium_case2_tot(
    params,
    verify=True))

# %% [markdown]
# # Plotting

# %% [markdown]
# ## Total sum

# %%
def total_sum_d0_vs_alpha():
    alpha = np.linspace(0, 1, 500)
    beta = 0.025
    gamma = 0.1
    delta = 0.2
    n = 4039
    d = 44
    e_top_s = 0.5*n

    params = (alpha, beta, gamma, delta, d, n, e_top_s)

    #thm_avg_equilibrium_expressed_opinions_general(alpha, beta, gamma, delta, d, n, e_top_s)

    myplt.cmp_funcs(params,
                     alpha, r'$\alpha$', r'$\bar{\tilde{\mathbf{z}}}^*$',
                     thm_tot.thm_avg_equilibrium_expressed_opinions_general, r'$\bar{\tilde \mathbf{z}}^*$',
                     yscale='linear', filename="auto")
total_sum_d0_vs_alpha()

# %%
def total_sum_d0_vs_beta():
    alpha = 0.5
    beta = np.linspace(0, 1, 500)
    gamma = 0.1
    delta = 0.2
    n = 4039
    d = 44
    e_top_s = 0.5*n

    params = (alpha, beta, gamma, delta, d, n, e_top_s)

    #thm_avg_equilibrium_expressed_opinions_general(alpha, beta, gamma, delta, d, n, e_top_s)

    myplt.cmp_funcs(params,
                     beta, r'$\beta$', r'$\bar{\tilde{\mathbf{z}}}^*$',
                     thm_tot.thm_avg_equilibrium_expressed_opinions_general, r'$\bar{\tilde \mathbf{z}}^*$',
                     yscale='linear', filename="auto")
total_sum_d0_vs_beta()

# %%
#Similar to Out et al. Fig 2b but with (but with different y-axis)
def total_sum_d0_vs_gamma():
    alpha = 0.5
    beta = 0.025
    gamma = np.linspace(0, 1, 500)
    delta = 0.2
    n = 4039
    d = 44
    e_top_s = 0.5*n

    params = (alpha, beta, gamma, delta, d, n, e_top_s)

    #thm_avg_equilibrium_expressed_opinions_general(alpha, beta, gamma, delta, d, n, e_top_s)

    myplt.cmp_funcs(params,
                     gamma, r'$\gamma$', r'$\bar{\tilde{\mathbf{z}}}^*$',
                     thm_tot.thm_avg_equilibrium_expressed_opinions_general, r'$\bar{\tilde \mathbf{z}}^*$',
                     #thmII.thm_sum_equilibrium_expressed_opinions_non_trunc, r'$sum$',
                     yscale='linear', filename="auto")
total_sum_d0_vs_gamma()

# %% [markdown]
# $M$ benefits from more biased media sources since it increases more in absolute values.

# %%
def total_sum_vs_delta():
    alpha = 0.5 #Why still growing when alpha < 0.5
    beta = 0.025
    gamma = 0.1
    delta = np.linspace(-1+alpha, 1-alpha, 500)
    n = 4039
    d = 44
    e_top_s = 0.5*n

    params = (alpha, beta, gamma, delta, d, n, e_top_s)

    #thm_avg_equilibrium_expressed_opinions_general(alpha, beta, gamma, delta, d, n, e_top_s)

    myplt.cmp_funcs(params,
                     delta, r'$\delta$', r'$\bar{\tilde{\mathbf{z}}}^*$',
                     thm_tot.thm_avg_equilibrium_expressed_opinions_general, r'$\bar{\tilde \mathbf{z}}^*$',
                     yscale='linear', filename="auto")
total_sum_vs_delta()

# %% [markdown]
# As $\delta$ grows, the differences in avarage initial opinions is greater. At some point, it doesn't help that the avarage opinion of $N(M)$ is greater, because $M$ already reach truncation.

# %% [markdown]
# ## Partial sums Case I

# %%
def M_and_M_prim_vs_beta():
    alpha = 0.6
    beta_values = np.linspace(0, 0.2, 500)
    gamma = 0.1
    delta = 0.000005
    n = 4039
    k = 0
    e_top_s = 1
    trunc=False

    myplt.cmp_funcs(alpha, beta_values, gamma, delta, k, n, e_top_s, trunc,
                     beta_values, r'$\beta$', r'$e^\top z$',
                     thmI.thm_sum_of_expressed_equilibrium_case2_M, r'$\mathbf{e}_M^\top \tilde \mathbf{z}^*$',
                     thmI.thm_sum_of_expressed_equilibrium_case2_M_prim, r'$\mathbf{e}_{Mprim}^\top \tilde \mathbf{z}^*$',
                     yscale='linear')
M_and_M_prim_vs_beta()

# %% [markdown]
# ## Partial sums Case II

# %%
def M_and_M_prim_vs_beta():
    alpha = 0.6
    beta_values = np.linspace(0, 0.2, 500)
    gamma = 0.1
    delta = 0.000005
    n = 4039
    k = 0
    e_top_s = 1
    trunc=False

    myplt.cmp_funcs(alpha, beta_values, gamma, delta, k, n, e_top_s, trunc,
                     beta_values, r'$\beta$', r'$e^\top z$',
                     thmII.thm_sum_of_expressed_equilibrium_case2_M, r'$\mathbf{e}_M^\top \tilde \mathbf{z}^*$',
                     thmII.thm_sum_of_expressed_equilibrium_case2_M_prim, r'$\mathbf{e}_{Mprim}^\top \tilde \mathbf{z}^*$',
                     yscale='linear')

# %%
def M_and_M_prim_vs_k():
    alpha = 0.75
    beta = 0.10
    gamma = 0.00001
    delta = 0.000005
    n = 4039
    k = np.linspace(0, ((int)(np.minimum(alpha * n, (1-alpha)*n))), 500)
    e_top_s = 1
    trunc=False

    myplt.cmp_funcs((alpha, beta, gamma, delta, k, n, e_top_s, trunc),
                     k, r'$\k$', r'$e^\top z$',
                     thmII.thm_sum_of_expressed_equilibrium_case2_M, r'$\mathbf{e}_M^\top \tilde \mathbf{z}^*$',
                     thmII.thm_sum_of_expressed_equilibrium_case2_M_prim, r'$\mathbf{e}_{Mprim}^\top \tilde \mathbf{z}^*$',
                     thmII.thm_sum_of_expressed_equilibrium_case2_tot, r'$\mathbf{e}^\top \tilde \mathbf{z}^*$',
                     yscale='linear')
M_and_M_prim_vs_k()

# %%
def M_and_M_prim_vs_k_smaller():
    alpha = 5/10
    beta = 0.2
    gamma = 0.01
    delta = 0.3
    n = 10
    k = np.linspace(0, ((int)(np.minimum(alpha * n, (1-alpha)*n))), 10)
    e_top_s = 1
    trunc=False
    
    params = (alpha, beta, gamma, delta, n, k, e_top_s, trunc)

    myplt.cmp_funcs(params,
                     k, r'$\k$', r'$e^\top z$',
                     thmII.thm_sum_of_expressed_equilibrium_case2_M, r'$\mathbf{e}_M^\top \tilde \mathbf{z}^*$',
                     thmII.thm_sum_of_expressed_equilibrium_case2_M_prim, r'$\mathbf{e}_{Mprim}^\top \tilde \mathbf{z}^*$',
                     thmII.thm_sum_of_expressed_equilibrium_case2_tot, r'$\mathbf{e}^\top \tilde \mathbf{z}^*$',
                     yscale='linear')

M_and_M_prim_vs_k_smaller()

# %%
def avg_M_and_M_prim_vs_k_smaller():
    alpha = 5/10
    beta = 0.2
    gamma = 0.01
    delta = 0.3
    n = 10
    k = np.linspace(0, ((int)(np.minimum(alpha * n, (1-alpha)*n))), 10)
    e_top_s = 1
    trunc=False
    
    params = (alpha, beta, gamma, delta, n, k, e_top_s, trunc)

    myplt.cmp_funcs(params,
                     k, r'$\k$', r'$e^\top z/n$',
                     thmII.thm_avg_of_expressed_equilibrium_case2_M, r'$\mathbf{e}_M^\top \tilde \mathbf{z}^*$',
                     thmII.thm_avg_of_expressed_equilibrium_case2_M_prim, r'$\mathbf{e}_{Mprim}^\top \tilde \mathbf{z}^*$',
                     thmII.thm_avg_of_expressed_equilibrium_case2_tot, r'$\mathbf{e}^\top \tilde \mathbf{z}^*$',
                     yscale='linear')

avg_M_and_M_prim_vs_k_smaller()

# %%
def avg_M_and_M_prim_vs_k_smaller_higher_n():
    alpha = 5/10
    beta = 0.002
    gamma = 0.9
    delta = 0.5
    n = 1000
    k = np.linspace(0, ((int)(np.minimum(alpha * n, (1-alpha)*n))), 100)
    e_top_s = 1
    trunc=False
    
    params = (alpha, beta, gamma, delta, n, k, e_top_s, trunc)

    myplt.cmp_funcs(params,
                     k, r'$\k$', r'$e^\top z/n$',
                     thmII.thm_avg_of_expressed_equilibrium_case2_M, r'$\mathbf{e}_M^\top \tilde \mathbf{z}^*$',
                     thmII.thm_avg_of_expressed_equilibrium_case2_M_prim, r'$\mathbf{e}_{Mprim}^\top \tilde \mathbf{z}^*$',
                     thmII.thm_avg_of_expressed_equilibrium_case2_tot, r'$\mathbf{e}^\top \tilde \mathbf{z}^*$',
                     yscale='linear')

avg_M_and_M_prim_vs_k_smaller_higher_n()

# %%
#Facebook / 20
def facebook_d20():
    alpha = 0.6 # TODO: Tune this
    beta = 0.025
    gamma = 0.1
    delta = 0.0000000 #TODO: Tune this. Why difference in avarage when 0?
    n = 4039 / 20
    n_1 = n*alpha
    print("n_1: ", n_1)
    n_2 = n*(1-alpha)
    print("n_2: ", n_2)
    k_max = ((int)(np.minimum(alpha * n, (1-alpha)*n)))
    print("k_max: ", k_max)
    k = np.linspace(0, 1*((int)(np.minimum(alpha * n, (1-alpha)*n))), 100)
    e_top_s = 1
    trunc=False
    
    params = (alpha, beta, gamma, delta, n, k, e_top_s, trunc)

    myplt.cmp_funcs(params,
                     k, r'$\k$', r'$e^\top z/n$',
                     thmII.thm_avg_of_expressed_equilibrium_case2_M, r'$\mathbf{e}_M^\top \tilde \mathbf{z}^*$',
                     thmII.thm_avg_of_expressed_equilibrium_case2_M_prim, r'$\mathbf{e}_{Mprim}^\top \tilde \mathbf{z}^*$',
                     thmII.thm_avg_of_expressed_equilibrium_case2_tot, r'$\mathbf{e}^\top \tilde \mathbf{z}^*$',
                     yscale='linear')
    k_0_diff = thmII.thm_avg_of_expressed_equilibrium_case2_M(params, verify=False) - \
               thmII.thm_avg_of_expressed_equilibrium_case2_M_prim(params, verify=False)
    
    k_max_diff = thmII.thm_avg_of_expressed_equilibrium_case2_M(params, verify=False) - \
               thmII.thm_avg_of_expressed_equilibrium_case2_M_prim(params, verify=False)
    print("k_0_diff:")
    print(k_0_diff)

    print("k_max_diff:")
    print(k_max_diff)
    
    print("diff factor:", k_max_diff/k_0_diff)
    

facebook_d20()

# %%
#Facebook
def facebook():
    alpha = 0.6 # TODO: Tune this
    beta = 0.025
    gamma = 0.1
    delta = 0.1 #TODO: Tune this
    n = 4039
    k_max = ((int)(np.minimum(alpha * n, (1-alpha)*n)))
    print("k_max: ", k_max)
    k = np.linspace(0, 1*((int)(np.minimum(alpha * n, (1-alpha)*n))), 100)
    e_top_s = 1
    trunc=False
    
    params = (alpha, beta, gamma, delta, n, k, e_top_s, trunc)

    myplt.cmp_funcs(params,
                     k, r'$\k$', r'$e^\top z/n$',
                     thmII.thm_avg_of_expressed_equilibrium_case2_M, r'$\mathbf{e}_M^\top \tilde \mathbf{z}^*$',
                     thmII.thm_avg_of_expressed_equilibrium_case2_M_prim, r'$\mathbf{e}_{Mprim}^\top \tilde \mathbf{z}^*$',
                     thmII.thm_avg_of_expressed_equilibrium_case2_tot, r'$\mathbf{e}^\top \tilde \mathbf{z}^*$',
                     yscale='linear')

facebook()

# %%
#Facebook with size / 20
def facebook_d20_vs_delta():
    alpha = 0.6 # TODO: Tune this
    beta = 0.025
    gamma = 0.1
    delta = np.linspace(0,1,100)
    n = 4039 / 20
    n_1 = n*alpha
    print("n_1: ", n_1)
    n_2 = n*(1-alpha)
    print("n_2: ", n_2)
    k_max = ((int)(np.minimum(alpha * n, (1-alpha)*n)))
    k = k_max
    e_top_s = n
    trunc=False
    
    params = (alpha, beta, gamma, delta, n, k, e_top_s, trunc)

    myplt.cmp_funcs(params,
                     delta, r'$\delta$', r'$e^\top z/n$',
                     thmII.thm_avg_of_expressed_equilibrium_case2_M, r'$\mathbf{e}_M^\top \tilde \mathbf{z}^*/n_1$',
                     thmII.thm_avg_of_expressed_equilibrium_case2_M_prim, r'$\mathbf{e}_{Mprim}^\top \tilde \mathbf{z}^*/n_2$',
                     thmII.thm_avg_of_expressed_equilibrium_case2_tot, r'$\mathbf{e}^\top \tilde \mathbf{z}^*/n$',
                     thmII.out_avg_of_expressed_equilibrium_case2_M, r'$\mathbf{e}_M^\top \hat \mathbf{z}^*/n_1$',
                     thmII.out_avg_of_expressed_equilibrium_case2_M_prim, r'$\mathbf{e}_{Mprim}^\top \hat \mathbf{z}^*/n_2$',
                     thmII.out_avg_of_expressed_equilibrium_case2_tot, r'$\mathbf{e}^\top \hat \mathbf{z}^*/n$',
                     yscale='linear')

facebook_d20_vs_delta()
