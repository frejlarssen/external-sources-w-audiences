# %% [markdown]
# # Imports

# %%
import src.numerical as naive
import src.theorems as thm
import src.plotting as myplt

import numpy as np

# %% [markdown]
# ## Verification

# %%
#Verification
thm.thm_sum_of_expressed_equilibrium_case2_M(
    alpha = 3/5,
    beta = 0.2*0,
    gamma = 0.1,
    delta = 0.25,
    n = 5,
    k = 2,
    e_top_s = 1,
    trunc=False,
    verify=True)

# %%
# All asserts passing!
print("thm_sum:",
thm.thm_sum_of_expressed_equilibrium_case2_tot(
    alpha = 30/50,
    beta = 0.2*0,
    gamma = 0.1,
    delta = 0.25,
    n = 50,
    k = 18,
    e_top_s = 1,
    trunc=False,
    verify=True))

# %% [markdown]
# # Plotting

# %%
def M_and_M_prim_vs_beta():
    alpha = 0.6
    beta_values = np.linspace(0, 0.2, 500)
    gamma = 0.1
    delta = 0.000005
    n = 4039
    k = 0
    e_top_s = 1
    trunc=False

    myplt.cmp_funcs(alpha, beta_values, gamma, delta, k, n, e_top_s, trunc,
                     beta_values, r'$\beta$', r'$e^\top z$',
                     thm.thm_sum_of_expressed_equilibrium_case2_M, r'$\mathbf{e}_M^\top \tilde \mathbf{z}^*$',
                     thm.thm_sum_of_expressed_equilibrium_case2_M_prim, r'$\mathbf{e}_{Mprim}^\top \tilde \mathbf{z}^*$',
                     yscale='linear')

# %%
def M_and_M_prim_vs_k():
    alpha = 0.75
    beta = 0.10
    gamma = 0.00001
    delta = 0.000005
    n = 4039
    k = np.linspace(0, ((int)(np.minimum(alpha * n, (1-alpha)*n))), 500)
    e_top_s = 1
    trunc=False

    myplt.cmp_funcs(alpha, beta, gamma, delta, k, n, e_top_s, trunc,
                     k, r'$\k$', r'$e^\top z$',
                     thm.thm_sum_of_expressed_equilibrium_case2_M, r'$\mathbf{e}_M^\top \tilde \mathbf{z}^*$',
                     thm.thm_sum_of_expressed_equilibrium_case2_M_prim, r'$\mathbf{e}_{Mprim}^\top \tilde \mathbf{z}^*$',
                     thm.thm_sum_of_expressed_equilibrium_case2_tot, r'$\mathbf{e}^\top \tilde \mathbf{z}^*$',
                     yscale='linear')
M_and_M_prim_vs_k()

# %%
def M_and_M_prim_vs_k_smaller():
    alpha = 5/10
    beta = 0.2
    gamma = 0.01
    delta = 0.3
    n = 10
    k = np.linspace(0, ((int)(np.minimum(alpha * n, (1-alpha)*n))), 10)
    e_top_s = 1
    trunc=False

    myplt.cmp_funcs(alpha, beta, gamma, delta, k, n, e_top_s, trunc,
                     k, r'$\k$', r'$e^\top z$',
                     thm.thm_sum_of_expressed_equilibrium_case2_M, r'$\mathbf{e}_M^\top \tilde \mathbf{z}^*$',
                     thm.thm_sum_of_expressed_equilibrium_case2_M_prim, r'$\mathbf{e}_{Mprim}^\top \tilde \mathbf{z}^*$',
                     thm.thm_sum_of_expressed_equilibrium_case2_tot, r'$\mathbf{e}^\top \tilde \mathbf{z}^*$',
                     yscale='linear')

M_and_M_prim_vs_k_smaller()

# %%
def avg_M_and_M_prim_vs_k_smaller():
    alpha = 5/10
    beta = 0.2
    gamma = 0.01
    delta = 0.3
    n = 10
    k = np.linspace(0, ((int)(np.minimum(alpha * n, (1-alpha)*n))), 10)
    e_top_s = 1
    trunc=False

    myplt.cmp_funcs(alpha, beta, gamma, delta, k, n, e_top_s, trunc,
                     k, r'$\k$', r'$e^\top z/n$',
                     thm.thm_avg_of_expressed_equilibrium_case2_M, r'$\mathbf{e}_M^\top \tilde \mathbf{z}^*$',
                     thm.thm_avg_of_expressed_equilibrium_case2_M_prim, r'$\mathbf{e}_{Mprim}^\top \tilde \mathbf{z}^*$',
                     thm.thm_avg_of_expressed_equilibrium_case2_tot, r'$\mathbf{e}^\top \tilde \mathbf{z}^*$',
                     yscale='linear')

avg_M_and_M_prim_vs_k_smaller()

# %%
def avg_M_and_M_prim_vs_k_smaller_higher_n():
    alpha = 5/10
    beta = 0.002
    gamma = 0.9
    delta = 0.5
    n = 1000
    k = np.linspace(0, ((int)(np.minimum(alpha * n, (1-alpha)*n))), 100)
    e_top_s = 1
    trunc=False

    myplt.cmp_funcs(alpha, beta, gamma, delta, k, n, e_top_s, trunc,
                     k, r'$\k$', r'$e^\top z/n$',
                     thm.thm_avg_of_expressed_equilibrium_case2_M, r'$\mathbf{e}_M^\top \tilde \mathbf{z}^*$',
                     thm.thm_avg_of_expressed_equilibrium_case2_M_prim, r'$\mathbf{e}_{Mprim}^\top \tilde \mathbf{z}^*$',
                     thm.thm_avg_of_expressed_equilibrium_case2_tot, r'$\mathbf{e}^\top \tilde \mathbf{z}^*$',
                     yscale='linear')

avg_M_and_M_prim_vs_k_smaller_higher_n()

# %%
#Facebook / 20
def facebook_d20():
    alpha = 0.6 # TODO: Tune this
    beta = 0.025
    gamma = 0.1
    delta = 0.0000000 #TODO: Tune this. Why difference in avarage when 0?
    n = 4039 / 20
    n_1 = n*alpha
    print("n_1: ", n_1)
    n_2 = n*(1-alpha)
    print("n_2: ", n_2)
    k_max = ((int)(np.minimum(alpha * n, (1-alpha)*n)))
    print("k_max: ", k_max)
    k = np.linspace(0, 1*((int)(np.minimum(alpha * n, (1-alpha)*n))), 100)
    e_top_s = 1
    trunc=False

    myplt.cmp_funcs(alpha, beta, gamma, delta, k, n, e_top_s, trunc,
                     k, r'$\k$', r'$e^\top z/n$',
                     thm.thm_avg_of_expressed_equilibrium_case2_M, r'$\mathbf{e}_M^\top \tilde \mathbf{z}^*$',
                     thm.thm_avg_of_expressed_equilibrium_case2_M_prim, r'$\mathbf{e}_{Mprim}^\top \tilde \mathbf{z}^*$',
                     thm.thm_avg_of_expressed_equilibrium_case2_tot, r'$\mathbf{e}^\top \tilde \mathbf{z}^*$',
                     yscale='linear')
    k_0_diff = thm.thm_avg_of_expressed_equilibrium_case2_M(alpha, beta, gamma, delta, 0, n, e_top_s, trunc = False, verify=False) - \
               thm.thm_avg_of_expressed_equilibrium_case2_M_prim(alpha, beta, gamma, delta, 0, n, e_top_s, trunc = False, verify=False)
    
    k_max_diff = thm.thm_avg_of_expressed_equilibrium_case2_M(alpha, beta, gamma, delta, k_max, n, e_top_s, trunc = False, verify=False) - \
               thm.thm_avg_of_expressed_equilibrium_case2_M_prim(alpha, beta, gamma, delta, k_max, n, e_top_s, trunc = False, verify=False)
    print("k_0_diff:")
    print(k_0_diff)

    print("k_max_diff:")
    print(k_max_diff)
    
    print("diff factor:", k_max_diff/k_0_diff)
    

facebook_d20()

# %%
#Facebook
def facebook():
    alpha = 0.6 # TODO: Tune this
    beta = 0.025
    gamma = 0.1
    delta = 0.1 #TODO: Tune this
    n = 4039
    k_max = ((int)(np.minimum(alpha * n, (1-alpha)*n)))
    print("k_max: ", k_max)
    k = np.linspace(0, 1*((int)(np.minimum(alpha * n, (1-alpha)*n))), 100)
    e_top_s = 1
    trunc=False

    myplt.cmp_funcs(alpha, beta, gamma, delta, k, n, e_top_s, trunc,
                     k, r'$\k$', r'$e^\top z/n$',
                     thm.thm_avg_of_expressed_equilibrium_case2_M, r'$\mathbf{e}_M^\top \tilde \mathbf{z}^*$',
                     thm.thm_avg_of_expressed_equilibrium_case2_M_prim, r'$\mathbf{e}_{Mprim}^\top \tilde \mathbf{z}^*$',
                     thm.thm_avg_of_expressed_equilibrium_case2_tot, r'$\mathbf{e}^\top \tilde \mathbf{z}^*$',
                     yscale='linear')

facebook()

# %%
#Facebook with size / 20
def facebook_d20_vs_delta():
    alpha = 0.6 # TODO: Tune this
    beta = 0.025
    gamma = 0.1
    delta = np.linspace(0,1,100)
    n = 4039 / 20
    n_1 = n*alpha
    print("n_1: ", n_1)
    n_2 = n*(1-alpha)
    print("n_2: ", n_2)
    k_max = ((int)(np.minimum(alpha * n, (1-alpha)*n)))
    k = k_max
    e_top_s = n
    trunc=False

    myplt.cmp_funcs(alpha, beta, gamma, delta, k, n, e_top_s, trunc,
                     delta, r'$\delta$', r'$e^\top z/n$',
                     thm.thm_avg_of_expressed_equilibrium_case2_M, r'$\mathbf{e}_M^\top \tilde \mathbf{z}^*/n_1$',
                     thm.thm_avg_of_expressed_equilibrium_case2_M_prim, r'$\mathbf{e}_{Mprim}^\top \tilde \mathbf{z}^*/n_2$',
                     thm.thm_avg_of_expressed_equilibrium_case2_tot, r'$\mathbf{e}^\top \tilde \mathbf{z}^*/n$',
                     thm.out_avg_of_expressed_equilibrium_case2_M, r'$\mathbf{e}_M^\top \hat \mathbf{z}^*/n_1$',
                     thm.out_avg_of_expressed_equilibrium_case2_M_prim, r'$\mathbf{e}_{Mprim}^\top \hat \mathbf{z}^*/n_2$',
                     thm.out_avg_of_expressed_equilibrium_case2_tot, r'$\mathbf{e}^\top \hat \mathbf{z}^*/n$',
                     yscale='linear')

facebook_d20_vs_delta()
